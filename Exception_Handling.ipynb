# %%
try:
     num = int(input("Enter a number: "))
except ValueError:
     print("Invalid input")
     except ZeroDivisionError:
else:
     print("You entered:", num)

# %%
try:
    num = int(input("Enter a number: "))
except ValueError:
    print("Invalid input")
else:
    print("You entered:", num)

# %%
try:
    num = int(input("Enter a number:"))
